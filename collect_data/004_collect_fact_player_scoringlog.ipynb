# %%
import pandas as pd
pd.options.display.max_columns = 40

# %%
df = pd.read_csv('/Users/mattrende/Documents/Coding/hockey-reference/YouTube Project/csv/in/jack_hughes_scoring_2023.csv')

player_name = 'Hughes, Jack'

# %%
df.head()
# Out:
#    Rk        Date   Tm Unnamed: 3  Opp  P   Time Unnamed: 7  \
# 0   1  2022-10-18  NJD        NaN  ANA  2  04:17         EV
# 1   2  2022-10-18  NJD        NaN  ANA  3  12:49         EV
# 2   3  2022-10-20  NJD          @  NYI  2  01:35         EV
# 3   4  2022-10-25  NJD          @  DET  1  15:16         EV
# 4   5  2022-10-25  NJD          @  DET  2  00:43         PP
#
#                                          Description
# 0  Goal by Ondřej Palát assisted by Ryan Graves a...
# 1  Goal by Dawson Mercer assisted by Yegor Sharan...
# 2     Goal by Jack Hughes assisted by Damon Severson
# 3  Goal by Jack Hughes assisted by Erik Haula and...
# 4  Goal by Jesper Bratt assisted by Jack Hughes a...

# %%
df.rename(columns={'Unnamed: 3':'Home','Unnamed: 7':'Goal_Strength'},inplace=True)

# %%
df['Date'] = df.Date.astype(str)
df['Date'] = df.Date.str.replace('-','')
df['Date'] = df.Date.astype(int)

# %%
## Lookup game number based on date
team_games = pd.read_csv("/Users/mattrende/Documents/Coding/hockey-reference/YouTube Project/csv/out/fact_gamelog.csv")
team_games.head(3)
# Out:
#           Key  team_id  Season_Year  GP Season      Date  Home  \
# 0  18-2023-R1       18         2023   1      R  20221013     0
# 1  18-2023-R2       18         2023   2      R  20221015     1
# 2  18-2023-R3       18         2023   3      R  20221018     1
#
#               Opp_Name  GF  GA Result  OT  Team_S  Team_PIM  Team_PPG  \
# 0  Philadelphia Flyers   2   5      L   0      37         8         1
# 1    Detroit Red Wings   2   5      L   0      39        12         0
# 2        Anaheim Ducks   4   2      W   0      41        15         0
#
#    Team_PPO  Team_SHG  Opp_S  Opp_PIM  Opp_PPG  Opp_PPO  Opp_SHG
# 0         3         0     25        8        1        3        0
# 1         3         0     22       10        0        4        0
# 2         3         0     20       23        0        4        0

# %%
df = df.merge(team_games, on=['Date'], how='left')
df.head(2)
# Out:
#    Rk      Date   Tm Home_x  Opp  P   Time Goal_Strength  \
# 0   1  20221018  NJD    NaN  ANA  2  04:17            EV
# 1   2  20221018  NJD    NaN  ANA  3  12:49            EV
#
#                                          Description         Key  team_id  \
# 0  Goal by Ondřej Palát assisted by Ryan Graves a...  18-2023-R3       18
# 1  Goal by Dawson Mercer assisted by Yegor Sharan...  18-2023-R3       18
#
#    Season_Year  GP Season  Home_y       Opp_Name  GF  GA Result  OT  Team_S  \
# 0         2023   3      R       1  Anaheim Ducks   4   2      W   0      41
# 1         2023   3      R       1  Anaheim Ducks   4   2      W   0      41
#
#    Team_PIM  Team_PPG  Team_PPO  Team_SHG  Opp_S  Opp_PIM  Opp_PPG  Opp_PPO  \
# 0        15         0         3         0     20       23        0        4
# 1        15         0         3         0     20       23        0        4
#
#    Opp_SHG
# 0        0
# 1        0

# %%
df['Description'][0]
# Out:
# 'Goal by Ondřej Palát assisted by Ryan Graves and Jack Hughes'

# %%
for desc in df['Description']:
    temp = desc.split(' ')[2:4]
    print(', '.join(reversed(temp)))
# Out:
# Palát, Ondřej
# Mercer, Dawson
# Hughes, Jack
# Hughes, Jack
# Bratt, Jesper
# Hughes, Jack
# Graves, Ryan
# Bratt, Jesper
# Hischier, Nico
# Hughes, Jack
# Bastian, Nathan
# Zetterlund, Fabian
# Tatar, Tomáš
# Hischier, Nico
# Hughes, Jack
# Hughes, Jack
# Hughes, Jack
# Bratt, Jesper
# Sharangovich, Yegor
# Bratt, Jesper
# Severson, Damon
# Hughes, Jack
# Hughes, Jack
# Hughes, Jack
# Hughes, Jack
# Hughes, Jack
# Bahl, Kevin
# Bratt, Jesper
# Hughes, Jack
# Hamilton, Dougie
# Bratt, Jesper
# Mercer, Dawson
# Hughes, Jack
# Hughes, Jack
# Hughes, Jack
# Marino, John
# Hughes, Jack
# Bratt, Jesper
# Hughes, Jack
# Hughes, Jack
# Hughes, Jack
# Hughes, Jack
# Hamilton, Dougie
# Hughes, Jack
# Hughes, Jack
# Hughes, Jack
# Hughes, Jack
# Bratt, Jesper
# Hughes, Jack
# Hughes, Jack
# Bratt, Jesper
# Hughes, Jack
# Tatar, Tomáš
# Okhotyuk, Nikita
# Hughes, Jack
# Hischier, Nico
# Hughes, Jack
# Hamilton, Dougie
# Hamilton, Dougie
# Hamilton, Dougie
# Sharangovich, Yegor
# Hughes, Jack
# Hughes, Jack
# Hughes, Jack
# Hughes, Jack
# Hughes, Jack
# Bratt, Jesper
# Hamilton, Dougie
# Bratt, Jesper
# Bratt, Jesper
# Mercer, Dawson
# Hischier, Nico
# Hughes, Jack
# Bratt, Jesper
# Bratt, Jesper
# Meier, Timo
# Hughes, Jack
# Bratt, Jesper
# Bratt, Jesper
# Severson, Damon
# Meier, Timo
# Bahl, Kevin
# Hughes, Jack
# Hughes, Jack
# Hughes, Jack
# Hamilton, Dougie
# Meier, Timo
# Hamilton, Dougie
# Boqvist, Jesper
# Hischier, Nico
# Meier, Timo
# Hughes, Jack
# Hughes, Jack
# Meier, Timo
# Meier, Timo
# Bratt, Jesper
# Hughes, Jack
# Haula, Erik
# Hughes, Luke

# %%
goal_scorer = []
primary_assist = []
secondary_assist = []

for desc in df['Description']:

    ## Populate Goal Scorer
    temp_gs = desc.split(' ')[2:4]
    temp_gs = ', '.join(reversed(temp_gs))
    goal_scorer.append(temp_gs)

    ## Populate Primary Assist
    try:
        temp_pa = desc.split(' ')[6:8]
        temp_pa = ', '.join(reversed(temp_pa))
        primary_assist.append(temp_pa)
    except:
        primary_assist.append(None)

    ## Populate Secondary Assist
    try:
        temp_sa = desc.split(' ')[9:11]
        temp_sa = ', '.join(reversed(temp_sa))
        secondary_assist.append(temp_sa)
    except:
        secondary_assist.append(None)

df['goal_scorer'] = goal_scorer
df['primary_assist'] = primary_assist
df['secondary_assist'] = secondary_assist
df['tracked_player_name'] = player_name

# %%
df.head(3)
# Out:
#    Rk      Date   Tm Home_x  Opp  P   Time Goal_Strength  \
# 0   1  20221018  NJD    NaN  ANA  2  04:17            EV
# 1   2  20221018  NJD    NaN  ANA  3  12:49            EV
# 2   3  20221020  NJD      @  NYI  2  01:35            EV
#
#                                          Description         Key  team_id  \
# 0  Goal by Ondřej Palát assisted by Ryan Graves a...  18-2023-R3       18
# 1  Goal by Dawson Mercer assisted by Yegor Sharan...  18-2023-R3       18
# 2     Goal by Jack Hughes assisted by Damon Severson  18-2023-R4       18
#
#    Season_Year  GP Season  Home_y            Opp_Name  GF  GA Result  OT  \
# 0         2023   3      R       1       Anaheim Ducks   4   2      W   0
# 1         2023   3      R       1       Anaheim Ducks   4   2      W   0
# 2         2023   4      R       0  New York Islanders   4   1      W   0
#
#    Team_S  Team_PIM  Team_PPG  Team_PPO  Team_SHG  Opp_S  Opp_PIM  Opp_PPG  \
# 0      41        15         0         3         0     20       23        0
# 1      41        15         0         3         0     20       23        0
# 2      43         6         0         3         0     17        8        0
#
#    Opp_PPO  Opp_SHG     goal_scorer       primary_assist secondary_assist  \
# 0        4        0   Palát, Ondřej         Graves, Ryan     Hughes, Jack
# 1        4        0  Mercer, Dawson  Sharangovich, Yegor     Hughes, Jack
# 2        2        0    Hughes, Jack      Severson, Damon
#
#   tracked_player_name
# 0        Hughes, Jack
# 1        Hughes, Jack
# 2        Hughes, Jack

# %%
df.rename(columns={'Key':'Team_Game_Key', 'Rk':'Point_Number'},inplace=True)
df.head(1)
# Out:
#    Point_Number      Date   Tm Home_x  Opp  P   Time Goal_Strength  \
# 0             1  20221018  NJD    NaN  ANA  2  04:17            EV
#
#                                          Description Team_Game_Key  team_id  \
# 0  Goal by Ondřej Palát assisted by Ryan Graves a...    18-2023-R3       18
#
#    Season_Year  GP Season  Home_y       Opp_Name  GF  GA Result  OT  Team_S  \
# 0         2023   3      R       1  Anaheim Ducks   4   2      W   0      41
#
#    Team_PIM  Team_PPG  Team_PPO  Team_SHG  Opp_S  Opp_PIM  Opp_PPG  Opp_PPO  \
# 0        15         0         3         0     20       23        0        4
#
#    Opp_SHG    goal_scorer primary_assist secondary_assist tracked_player_name
# 0        0  Palát, Ondřej   Graves, Ryan     Hughes, Jack        Hughes, Jack

# %% [markdown]
# #### Reorder columns

# %%
df = df[['tracked_player_name','Point_Number', 'Team_Game_Key', 'P', 'Time', 'Goal_Strength',
       'Description', 'goal_scorer', 'primary_assist', 'secondary_assist']]

# %%
df.head()
# Out:
#   tracked_player_name  Point_Number Team_Game_Key  P   Time Goal_Strength  \
# 0        Hughes, Jack             1    18-2023-R3  2  04:17            EV
# 1        Hughes, Jack             2    18-2023-R3  3  12:49            EV
# 2        Hughes, Jack             3    18-2023-R4  2  01:35            EV
# 3        Hughes, Jack             4    18-2023-R7  1  15:16            EV
# 4        Hughes, Jack             5    18-2023-R7  2  00:43            PP
#
#                                          Description     goal_scorer  \
# 0  Goal by Ondřej Palát assisted by Ryan Graves a...   Palát, Ondřej
# 1  Goal by Dawson Mercer assisted by Yegor Sharan...  Mercer, Dawson
# 2     Goal by Jack Hughes assisted by Damon Severson    Hughes, Jack
# 3  Goal by Jack Hughes assisted by Erik Haula and...    Hughes, Jack
# 4  Goal by Jesper Bratt assisted by Jack Hughes a...   Bratt, Jesper
#
#         primary_assist  secondary_assist
# 0         Graves, Ryan      Hughes, Jack
# 1  Sharangovich, Yegor      Hughes, Jack
# 2      Severson, Damon
# 3          Haula, Erik     Bratt, Jesper
# 4         Hughes, Jack  Hamilton, Dougie

# %% [markdown]
# #### Export to CSV

# %%
df.to_csv('/Users/mattrende/Documents/Coding/hockey-reference/YouTube Project/csv/out/fact_jack_2023_scoringlog.csv',index=False)
