# %%
import pandas as pd
pd.options.display.max_columns = 40

# %% [markdown]
# #### Load data from CSV

# %%
df = pd.read_csv("/Users/mattrende/Documents/Coding/hockey-reference/YouTube Project/csv/in/njd_2020.csv")

team_abv = 'NJD'
season = '2020'
reg_or_playoffs = 'R'

# %%
df.head(3)
# Out:
#   Unnamed: 0  Unnamed: 1 Unnamed: 2      Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         GP        Date        NaN        Opponent         GF         GA
# 1          1  2019-10-04        NaN   Winnipeg Jets          4          5
# 2          2  2019-10-05          @  Buffalo Sabres          2          7
#
#   Unnamed: 6 Unnamed: 7  Unnamed: 8 Team Team.1 Team.2 Team.3 Team.4  \
# 0        NaN        NaN         NaN    S    PIM    PPG    PPO    SHG
# 1          L         SO         NaN   39      4      0      2      0
# 2          L        NaN         NaN   20     20      0      2      0
#
#    Unnamed: 14 Opponent Opponent.1 Opponent.2 Opponent.3 Opponent.4  \
# 0          NaN        S        PIM        PPG        PPO        SHG
# 1          NaN       30          4          0          2          0
# 2          NaN       36         16          3          4          0
#
#    Unnamed: 20 Advanced (at Even Strength) Advanced (at Even Strength).1  \
# 0          NaN                          CF                            CA
# 1          NaN                          49                            47
# 2          NaN                          32                            46
#
#   Advanced (at Even Strength).2 Advanced (at Even Strength).3  \
# 0                           CF%                            FF
# 1                          51.0                            44
# 2                          41.0                            23
#
#   Advanced (at Even Strength).4 Advanced (at Even Strength).5  \
# 0                            FA                           FF%
# 1                            40                          52.4
# 2                            37                          38.3
#
#   Advanced (at Even Strength).6 Advanced (at Even Strength).7  \
# 0                           FOW                           FOL
# 1                            23                            23
# 2                            20                            20
#
#   Advanced (at Even Strength).8 Advanced (at Even Strength).9  \
# 0                           FO%                          oZS%
# 1                          50.0                          31.4
# 2                          50.0                          30.4
#
#   Advanced (at Even Strength).10
# 0                            PDO
# 1                          100.0
# 2                           98.5

# %%
df = df.loc[:, :"Opponent.4"]
df.head(2)
# Out:
#   Unnamed: 0  Unnamed: 1 Unnamed: 2     Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         GP        Date        NaN       Opponent         GF         GA
# 1          1  2019-10-04        NaN  Winnipeg Jets          4          5
#
#   Unnamed: 6 Unnamed: 7  Unnamed: 8 Team Team.1 Team.2 Team.3 Team.4  \
# 0        NaN        NaN         NaN    S    PIM    PPG    PPO    SHG
# 1          L         SO         NaN   39      4      0      2      0
#
#    Unnamed: 14 Opponent Opponent.1 Opponent.2 Opponent.3 Opponent.4
# 0          NaN        S        PIM        PPG        PPO        SHG
# 1          NaN       30          4          0          2          0

# %%
df.drop(columns=["Unnamed: 8","Unnamed: 14"],inplace=True)
df.head(3)
# Out:
#   Unnamed: 0  Unnamed: 1 Unnamed: 2      Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         GP        Date        NaN        Opponent         GF         GA
# 1          1  2019-10-04        NaN   Winnipeg Jets          4          5
# 2          2  2019-10-05          @  Buffalo Sabres          2          7
#
#   Unnamed: 6 Unnamed: 7 Team Team.1 Team.2 Team.3 Team.4 Opponent Opponent.1  \
# 0        NaN        NaN    S    PIM    PPG    PPO    SHG        S        PIM
# 1          L         SO   39      4      0      2      0       30          4
# 2          L        NaN   20     20      0      2      0       36         16
#
#   Opponent.2 Opponent.3 Opponent.4
# 0        PPG        PPO        SHG
# 1          0          2          0
# 2          3          4          0

# %%
df.rename(columns={'Unnamed: 0':'GP', 'Unnamed: 1':"Date", 'Unnamed: 2':"Home", 'Unnamed: 3':"Opp_Name", 'Unnamed: 4':"GF",
       'Unnamed: 5':"GA", 'Unnamed: 6':"Result", 'Unnamed: 7':"OT", 'Team':"Team_S", 'Team.1':"Team_PIM", 'Team.2':"Team_PPG",
       'Team.3':"Team_PPO", 'Team.4':"Team_SHG", 'Opponent':"Opp_S", 'Opponent.1':"Opp_PIM", 'Opponent.2':"Opp_PPG",
       'Opponent.3':"Opp_PPO", 'Opponent.4':"Opp_SHG"},inplace=True)

df.head(2)
# Out:
#    GP        Date Home       Opp_Name  GF  GA Result   OT Team_S Team_PIM  \
# 0  GP        Date  NaN       Opponent  GF  GA    NaN  NaN      S      PIM
# 1   1  2019-10-04  NaN  Winnipeg Jets   4   5      L   SO     39        4
#
#   Team_PPG Team_PPO Team_SHG Opp_S Opp_PIM Opp_PPG Opp_PPO Opp_SHG
# 0      PPG      PPO      SHG     S     PIM     PPG     PPO     SHG
# 1        0        2        0    30       4       0       2       0

# %%
df.drop(0,inplace=True)
df.head(2)
# Out:
#   GP        Date Home        Opp_Name GF GA Result   OT Team_S Team_PIM  \
# 1  1  2019-10-04  NaN   Winnipeg Jets  4  5      L   SO     39        4
# 2  2  2019-10-05    @  Buffalo Sabres  2  7      L  NaN     20       20
#
#   Team_PPG Team_PPO Team_SHG Opp_S Opp_PIM Opp_PPG Opp_PPO Opp_SHG
# 1        0        2        0    30       4       0       2       0
# 2        0        2        0    36      16       3       4       0

# %%
df.tail(10)
# Out:
#     GP        Date Home              Opp_Name GF GA Result   OT Team_S  \
# 60  60  2020-02-20  NaN       San Jose Sharks  2  1      W  NaN     25
# 61  61  2020-02-22  NaN   Washington Capitals  3  2      W  NaN     29
# 62  62  2020-02-25    @     Detroit Red Wings  4  1      W  NaN     31
# 63  63  2020-02-27    @       San Jose Sharks  2  3      L   OT     23
# 64  64  2020-02-29    @     Los Angeles Kings  1  2      L   OT     33
# 65  65  2020-03-01    @         Anaheim Ducks  3  0      W  NaN     34
# 66  66  2020-03-03    @  Vegas Golden Knights  0  3      L  NaN     27
# 67  67  2020-03-06  NaN       St. Louis Blues  4  2      W  NaN     32
# 68  68  2020-03-07    @      New York Rangers  6  4      W  NaN     29
# 69  69  2020-03-10  NaN   Pittsburgh Penguins  2  5      L  NaN     22
#
#    Team_PIM Team_PPG Team_PPO Team_SHG Opp_S Opp_PIM Opp_PPG Opp_PPO Opp_SHG
# 60       11        1        6        0    37      17       0       3       0
# 61       14        2        3        0    35       8       1       6       0
# 62       31        3        5        0    28      20       1       4       0
# 63        8        0        4        0    30      10       0       3       1
# 64        0        0        1        0    38       2       0       0       0
# 65        4        2        3        0    34       6       0       2       0
# 66        2        0        3        0    32       6       0       1       0
# 67        8        0        2        0    33       4       1       4       0
# 68        6        1        1        0    35       2       0       3       0
# 69        8        1        3        0    33       6       0       4       0

# %%
df.Home = [0 if x == "@" else 1 for x in df.Home]


df.OT = [1 if x == "OT" else 0 for x in df.OT]

# %%
df['Team_Abv'] = team_abv
df['Season'] = reg_or_playoffs
df['Season_Year'] = season

# %%
df.head(2)
# Out:
#   GP        Date  Home        Opp_Name GF GA Result  OT Team_S Team_PIM  \
# 1  1  2019-10-04     1   Winnipeg Jets  4  5      L   0     39        4
# 2  2  2019-10-05     0  Buffalo Sabres  2  7      L   0     20       20
#
#   Team_PPG Team_PPO Team_SHG Opp_S Opp_PIM Opp_PPG Opp_PPO Opp_SHG Team_Abv  \
# 1        0        2        0    30       4       0       2       0      NJD
# 2        0        2        0    36      16       3       4       0      NJD
#
#   Season Season_Year
# 1      R        2020
# 2      R        2020

# %%
abv_team_names = pd.read_csv("/Users/mattrende/Documents/Coding/hockey-reference/YouTube Project/csv/in/team_abv.csv")
abv_team_names.head(3)
# Out:
#    ABV             Team  ID
# 0  ANA    Anaheim Ducks   1
# 1  ARI  Arizona Coyotes   2
# 2  BOS    Boston Bruins   3

# %%
df = df.merge(abv_team_names, left_on=['Team_Abv'],right_on=["ABV"], how='left')
df.head(2)
# Out:
#   GP        Date  Home        Opp_Name GF GA Result  OT Team_S Team_PIM  \
# 0  1  2019-10-04     1   Winnipeg Jets  4  5      L   0     39        4
# 1  2  2019-10-05     0  Buffalo Sabres  2  7      L   0     20       20
#
#   Team_PPG Team_PPO Team_SHG Opp_S Opp_PIM Opp_PPG Opp_PPO Opp_SHG Team_Abv  \
# 0        0        2        0    30       4       0       2       0      NJD
# 1        0        2        0    36      16       3       4       0      NJD
#
#   Season Season_Year  ABV               Team  ID
# 0      R        2020  NJD  New Jersey Devils  18
# 1      R        2020  NJD  New Jersey Devils  18

# %%
df.rename(columns={'ID':"team_id"},inplace=True)

# %%
df.drop(columns='ABV',inplace=True)

# %% [markdown]
# #### Create primary key

# %%
df["Key"] = df["team_id"].astype(str) + "-" + season + "-" + reg_or_playoffs + df["GP"].astype(str)

# %%
# Cleanup date
df['Date'] = df.Date.astype(str)
df['Date'] = df.Date.str.replace('-','')

# %%
df.head(2)
# Out:
#   GP      Date  Home        Opp_Name GF GA Result  OT Team_S Team_PIM  \
# 0  1  20191004     1   Winnipeg Jets  4  5      L   0     39        4
# 1  2  20191005     0  Buffalo Sabres  2  7      L   0     20       20
#
#   Team_PPG Team_PPO Team_SHG Opp_S Opp_PIM Opp_PPG Opp_PPO Opp_SHG Team_Abv  \
# 0        0        2        0    30       4       0       2       0      NJD
# 1        0        2        0    36      16       3       4       0      NJD
#
#   Season Season_Year               Team  team_id         Key
# 0      R        2020  New Jersey Devils       18  18-2020-R1
# 1      R        2020  New Jersey Devils       18  18-2020-R2

# %% [markdown]
# #### Reorder Columns

# %%
df.columns
# Out:
# Index(['GP', 'Date', 'Home', 'Opp_Name', 'GF', 'GA', 'Result', 'OT', 'Team_S',
#        'Team_PIM', 'Team_PPG', 'Team_PPO', 'Team_SHG', 'Opp_S', 'Opp_PIM',
#        'Opp_PPG', 'Opp_PPO', 'Opp_SHG', 'Team_Abv', 'Season', 'Season_Year',
#        'Team', 'team_id', 'Key'],
#       dtype='object')

# %%
df = df[['Key','team_id','Season_Year','GP','Season','Date','Home','Opp_Name','GF','GA','Result','OT','Team_S','Team_PIM', 
    'Team_PPG', 'Team_PPO', 'Team_SHG', 'Opp_S', 'Opp_PIM', 'Opp_PPG', 'Opp_PPO', 'Opp_SHG']]

# %% [markdown]
# #### Export to CSV

# %%
df.to_csv('/Users/mattrende/Documents/Coding/hockey-reference/YouTube Project/csv/out/fact_gamelog_2020.csv',index=False)
