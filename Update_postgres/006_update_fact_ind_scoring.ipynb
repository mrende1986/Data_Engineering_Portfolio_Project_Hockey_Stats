# %%
import psycopg2
import pandas as pd
pd.options.display.max_columns = 40

# %% [markdown]
# ### Import raw dataset
#
# #### Challenge - Build code to collect data directly from hockey-reference.com

# %%
df = pd.read_csv('/Users/mattrende/Documents/Coding/hockey-reference/YouTube Project/csv/in/jack_hughes_scoring_2023.csv')
team_games = pd.read_csv("/Users/mattrende/Documents/Coding/hockey-reference/YouTube Project/csv/out/fact_gamelog.csv")
player_name = 'Hughes, Jack'

# %%
df['Date'] = df.Date.astype(str)
df['Date'] = df.Date.str.replace('-','')
df['Date'] = df.Date.astype(int)

# %%
df = df.merge(team_games, on=['Date'], how='left')

# %%
df.rename(columns={'Unnamed: 3':'Home','Unnamed: 7':'Goal_Strength','Key':'Team_Game_Key', 'Rk':'Point_Number'},inplace=True)

# %%
goal_scorer = []
primary_assist = []
secondary_assist = []

for desc in df['Description']:

    ## Populate Goal Scorer
    temp_gs = desc.split(' ')[2:4]
    temp_gs = ', '.join(reversed(temp_gs))
    goal_scorer.append(temp_gs)

    ## Populate Primary Assist
    try:
        temp_pa = desc.split(' ')[6:8]
        temp_pa = ', '.join(reversed(temp_pa))
        primary_assist.append(temp_pa)
    except:
        primary_assist.append(None)

    ## Populate Secondary Assist
    try:
        temp_sa = desc.split(' ')[9:11]
        temp_sa = ', '.join(reversed(temp_sa))
        secondary_assist.append(temp_sa)
    except:
        secondary_assist.append(None)

df['goal_scorer'] = goal_scorer
df['primary_assist'] = primary_assist
df['secondary_assist'] = secondary_assist
df['tracked_player_name'] = player_name

# %%
df.head()
# Out:
#    Point_Number      Date   Tm  Home  Opp  P   Time Goal_Strength  \
# 0             1  20221018  NJD   NaN  ANA  2  04:17            EV
# 1             2  20221018  NJD   NaN  ANA  3  12:49            EV
# 2             3  20221020  NJD     @  NYI  2  01:35            EV
# 3             4  20221025  NJD     @  DET  1  15:16            EV
# 4             5  20221025  NJD     @  DET  2  00:43            PP
#
#                                          Description Team_Game_Key  team_id  \
# 0  Goal by Ondřej Palát assisted by Ryan Graves a...    18-2023-R3       18
# 1  Goal by Dawson Mercer assisted by Yegor Sharan...    18-2023-R3       18
# 2     Goal by Jack Hughes assisted by Damon Severson    18-2023-R4       18
# 3  Goal by Jack Hughes assisted by Erik Haula and...    18-2023-R7       18
# 4  Goal by Jesper Bratt assisted by Jack Hughes a...    18-2023-R7       18
#
#    Season_Year  GP Season  Home            Opp_Name  GF  GA Result  OT  \
# 0         2023   3      R     1       Anaheim Ducks   4   2      W   0
# 1         2023   3      R     1       Anaheim Ducks   4   2      W   0
# 2         2023   4      R     0  New York Islanders   4   1      W   0
# 3         2023   7      R     0   Detroit Red Wings   6   2      W   0
# 4         2023   7      R     0   Detroit Red Wings   6   2      W   0
#
#    Team_S  Team_PIM  Team_PPG  Team_PPO  Team_SHG  Opp_S  Opp_PIM  Opp_PPG  \
# 0      41        15         0         3         0     20       23        0
# 1      41        15         0         3         0     20       23        0
# 2      43         6         0         3         0     17        8        0
# 3      41         6         1         1         1     22        2        0
# 4      41         6         1         1         1     22        2        0
#
#    Opp_PPO  Opp_SHG     goal_scorer       primary_assist  secondary_assist  \
# 0        4        0   Palát, Ondřej         Graves, Ryan      Hughes, Jack
# 1        4        0  Mercer, Dawson  Sharangovich, Yegor      Hughes, Jack
# 2        2        0    Hughes, Jack      Severson, Damon
# 3        3        0    Hughes, Jack          Haula, Erik     Bratt, Jesper
# 4        3        0   Bratt, Jesper         Hughes, Jack  Hamilton, Dougie
#
#   tracked_player_name
# 0        Hughes, Jack
# 1        Hughes, Jack
# 2        Hughes, Jack
# 3        Hughes, Jack
# 4        Hughes, Jack

# %% [markdown]
# #### Connect to database

# %%
try:
    conn = psycopg2.connect("host=127.0.0.1 dbname=hockey_yt_project user=postgres password=password")
except psycopg2.Error as e:
    print("Error: Could not connect to database")
    print(e)

try:
    cur = conn.cursor()
except psycopg2.Error as e:
    print("Error: Could not get cursor to the database")
    print(e)

conn.set_session(autocommit=True)

# %% [markdown]
# #### Find last game in database

# %%
try: 
    cur.execute("""select max(g.date)
                   from fact_player_scoring_log p
                   join fact_gamelog g
	               on g.key = p.team_year_gp_key;""")

except psycopg2.Error as e:
    print("Select Error")
    print(e)

row = cur.fetchone()
games_in_db = []
while row:
    last_game_in_db = row[0]
    row = cur.fetchone()

# %%
last_game_in_db
# Out:
# 20230413

# %% [markdown]
# #### Filter for rows after last game in db

# %%
missing_points = df[df.Date > last_game_in_db]
missing_points = missing_points[['tracked_player_name','Point_Number', 'Team_Game_Key', 'P', 'Time', 'Goal_Strength',
       'Description', 'goal_scorer', 'primary_assist', 'secondary_assist']]
missing_points.head()
# Out:
# Empty DataFrame
# Columns: [tracked_player_name, Point_Number, Team_Game_Key, P, Time, Goal_Strength, Description, goal_scorer, primary_assist, secondary_assist]
# Index: []

# %%
player_scoring_insert = ("""INSERT INTO fact_player_scoring_log(
                  tracked_player_name,
                  point_number,
                  team_year_gp_key,
                  p,
                  time,
                  goal_strength,
                  description,
                  goal_scorer,
                  primary_assist,
                  secondary_assist)
               VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
               """)

# %% [markdown]
# #### Insert into DB

# %%
try:
    for i, row in missing_points.iterrows():
        #print(list(row))
        cur.execute(player_scoring_insert, list(row))

except psycopg2.Error as e:
    print("Error: could not insert rows")
    print(e)
